# %% [markdown]
# # Assignment1
#      Clayton Cohn
#      April 2, 2020
#      DSC478
#      Prof. Mobasher

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
DATA_PATH = '/Users/claytoncohn/Dropbox/New/DePaul/DSC478/data/bank_data.csv'

# %%
df = pd.read_csv(DATA_PATH, delimiter=',', header=None, names=['id', 'age', 'income', 'children','gender','region',
                                                               'married','car','save_account','current_account',
                                                               'mortgage','pep'])

# %%
df.shape
df.sample(10)
# Out:
#           id age   income children  gender    religion married  car  \
# 158  ID12258  24  20467.3        2    MALE       RURAL     YES  YES
# 422  ID12522  49    41438        1    MALE  INNER_CITY      NO   NO
# 330  ID12430  27  18555.9        3  FEMALE        TOWN     YES   NO
# 329  ID12429  57  50849.2        1  FEMALE       RURAL      NO   NO
# 269  ID12369  63  34625.2        0  FEMALE        TOWN     YES  YES
# 14   ID12114  66  55204.7        1  FEMALE        TOWN     YES  YES
# 284  ID12384  43  39175.8        3  FEMALE  INNER_CITY     YES   NO
# 273  ID12373  36  13236.4        0    MALE        TOWN     YES   NO
# 520  ID12620  56  28981.1        3  FEMALE  INNER_CITY     YES  YES
# 441  ID12541  40  29414.6        1    MALE  INNER_CITY     YES   NO
#
#     save_account current_account mortgage  pep
# 158          YES             YES       NO   NO
# 422          YES              NO       NO  YES
# 330           NO             YES       NO   NO
# ...
